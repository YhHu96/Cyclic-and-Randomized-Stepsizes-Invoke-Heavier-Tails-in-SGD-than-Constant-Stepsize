# %%
import numpy as np

# %%
lr_list = [0.14,0.15,0.16,0.17,0.18,0.19,0.2,0.21,0.22]

# delta = 0.05
alpha_unif = [1.9992081559596,
 2.0058759615058332,
 1.9966414023637025,
 1.9888339310322185,
 1.3223480616710073,
 1.1545610117347485,
 1.0441591429818526,
 0.9973064473474609,
 0.9672450767340022]

alpha_const = [2.0076225726704817,
 1.993290836651396,
 2.009862545076988,
 2.0058438625085917,
 1.831623996601687,
 1.470831536025423,
 1.3533148198418132,
 1.2454126140725206,
 1.1417129926018952]

# p = 0.6
alpha_mc = [2.002046524425199,
 1.9993057626601152,
 1.9646224357506248,
 1.6161651157544217,
 0.9808721745312605,
 0.9275423196270094,
 0.89077630510346,
 0.9537082539371149,
 0.9743876057367452]

alpha_cyc = [1.9991720893978229,
 2.011298303694093,
 2.0008479594466153,
 1.9874978527323601,
 1.5428267534633262,
 1.3720664714152018,
 1.269155771649106,
 1.1805871763417242,
 1.0950724369206228]

alpha_lower = [1.99583675026005,
 2.0122145594803498,
 1.996048906029783,
 1.9950367059264706,
 2.004977513702677,
 1.9973217012957465,
 2.0072649318091154,
 2.0039254246749505,
 2.0048269735745183]

alpha_upper = [1.503881464560734,
 1.3665886277761965,
 1.2650602704559242,
 1.1628364962942015,
 1.047825392474475,
 0.9985003764905789,
 0.9939563427605188,
 0.9236492483200796,
 0.9019350759233753]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7.5))
# plt.plot(lr_list, alpha_lower, linewidth = 3)
plt.plot(lr_list[:-1], alpha_const[:-1], linewidth = 3)
# plt.plot(lr_list, alpha_upper, linewidth = 3)
plt.plot(lr_list[:-1], alpha_unif[:-1], linewidth = 3)
plt.plot(lr_list[:-1], alpha_cyc[:-1], linewidth = 3)
plt.plot(lr_list[:-1], alpha_mc[:-1], linewidth = 3)

plt.xlabel(r'Mean of learning rate $\hat{\eta}$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
# bbox_to_anchor=(1.04,0.5)
legendList = [r'Constant $\hat{\eta}$','Uniform','Cyclic',r'Markovian $p=0.6$']
plt.legend(legendList, loc='best', fontsize=21)
plt.show()

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7.5))
plt.plot(lr_list, alpha_const, linewidth = 3)
plt.plot(lr_list, alpha_unif, linewidth = 3)
plt.plot(lr_list, alpha_cyc, linewidth = 3)
plt.plot(lr_list, alpha_mc, linewidth = 3)

plt.xlabel(r'Mean of learning rate $\hat{\eta}$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
# bbox_to_anchor=(1.04,0.5)
legendList = ['Constant lr','Uniform lr','Cyclic lr',r'MC lr $p=0.6$']
plt.legend(legendList, loc='best', fontsize=23)
plt.show()

# %%
# cyclic lr with different delta values
alpha_05 = [1.9991720893978229,
 2.011298303694093,
 2.0008479594466153,
 1.9874978527323601,
 1.5428267534633262,
 1.3720664714152018,
 1.269155771649106,
 1.1805871763417242,
 1.0950724369206228]

alpha_04 = [2.010257077015096,
 1.9959846996481365,
 1.9969430626601021,
 2.0066238209404803,
 1.6394994794382476,
 1.411773549362355,
 1.2847618578441176,
 1.194561979482453,
 1.1292451612829693]

alpha_03 = [2.016491455379517,
 2.0041872085830015,
 2.0042979040720605,
 2.008191658435959,
 1.745028696130977,
 1.4325435968283107,
 1.3165325322369972,
 1.2202257410979607,
 1.120917055548965]

alpha_02 = [2.000209075470449,
 2.007560240609068,
 2.012672405698283,
 1.9889764183431058,
 1.812992803698751,
 1.4773446996961004,
 1.3431437900133798,
 1.2307946095174598,
 1.135341374389148]

alpha_const = [2.0076225726704817,
 1.993290836651396,
 2.009862545076988,
 2.0058438625085917,
 1.831623996601687,
 1.470831536025423,
 1.3533148198418132,
 1.2454126140725206,
 1.1417129926018952]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7.5))
plt.plot(lr_list, alpha_const, linewidth = 3)
plt.plot(lr_list, alpha_02, linewidth = 3)
plt.plot(lr_list, alpha_03, linewidth = 3)
plt.plot(lr_list, alpha_04, linewidth = 3)
plt.plot(lr_list, alpha_05, linewidth = 3)

plt.xlabel(r'Mean of learning rate $\hat{\eta}$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
# bbox_to_anchor=(1.04,0.5)
legendList = [r'$R=0$',r'$R = 0.02$',r'$R = 0.03$',r'$R = 0.04$',r'$R = 0.05$']
plt.legend(legendList, loc='best', fontsize=23)
plt.show()

# %%
# uniform lr with different delta values
alpha_05 = [1.9992081559596,
 2.0058759615058332,
 1.9966414023637025,
 1.9888339310322185,
 1.3223480616710073,
 1.1545610117347485,
 1.0441591429818526,
 0.9973064473474609,
 0.9672450767340022]

alpha_04 = [1.9980193521187706,
 1.994331313377948,
 2.008449962798776,
 1.9844368268515886,
 1.489800381785496,
 1.2522119658060922,
 1.127180064050747,
 1.0632379306684896,
 1.0201058997358983]

alpha_03 = [2.011808171891638,
 2.006497365754277,
 2.002973731131015,
 2.0011681103124825,
 1.6433117890744189,
 1.3396652156058708,
 1.2336902234418194,
 1.1191617514907952,
 1.0423329315758816]

alpha_02 = [2.001870966800299,
 1.9957802846557626,
 2.0084541341950914,
 1.9965154018900835,
 1.7738066631121632,
 1.4228938197647925,
 1.2755673483361696,
 1.1941087136869475,
 1.1101158020743571]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7.5))
plt.plot(lr_list, alpha_const, linewidth = 3)
plt.plot(lr_list, alpha_02, linewidth = 3)
plt.plot(lr_list, alpha_03, linewidth = 3)
plt.plot(lr_list, alpha_04, linewidth = 3)
plt.plot(lr_list, alpha_05, linewidth = 3)

plt.xlabel(r'Mean of learning rate $\hat{\eta}$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
# bbox_to_anchor=(1.04,0.5)
legendList = [r'$R=0$',r'$R = 0.02$',r'$R = 0.03$',r'$R = 0.04$',r'$R = 0.05$']
plt.legend(legendList, loc='best', fontsize=23)
plt.show()

# %%
# mc lr with different delta values
# p=0.6
alpha_05 = [2.002046524425199,
 1.9993057626601152,
 1.9646224357506248,
 1.6161651157544217,
 0.9808721745312605,
 0.9275423196270094,
 0.89077630510346,
 0.8537082539371149,
 0.8743876057367452]

alpha_04 = [2.003700207690419,
 1.9900085141581865,
 2.0001431910110257,
 1.9076964829958,
 1.0093872016052483,
 0.9276954382106143,
 0.9462614555706806,
 0.880042709143689,
 0.8789562301814527]

alpha_03 = [2.007280386000215,
 1.9939633787725872,
 1.9955746841220696,
 1.97388027583118,
 1.2914704606043201,
 1.0102961431068678,
 0.9508711819200671,
 0.9437380010007425,
 0.9507508789632385]

alpha_02 = [2.0047487984136514,
 2.0059994843976887,
 1.997108063889702,
 2.0056116939510145,
 1.5831318591564758,
 1.1827401448809856,
 1.0605788271248406,
 1.0247408290307496,
 0.9611613405087753]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7.5))
plt.plot(lr_list, alpha_const, linewidth = 3)
plt.plot(lr_list, alpha_02, linewidth = 3)
plt.plot(lr_list, alpha_03, linewidth = 3)
plt.plot(lr_list, alpha_04, linewidth = 3)
plt.plot(lr_list, alpha_05, linewidth = 3)

plt.xlabel(r'Mean of learning rate $\hat{\eta}$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
# bbox_to_anchor=(1.04,0.5)
legendList = [r'$R=0$',r'$R = 0.02$',r'$R = 0.03$',r'$R = 0.04$',r'$R = 0.05$']
plt.legend(legendList, loc='best', fontsize=23)
plt.show()

# %%
# mc lr with different p values
# delta=0.05
alpha_06 = [2.002046524425199,
 1.9993057626601152,
 1.9646224357506248,
 1.6161651157544217,
 0.9808721745312605,
 0.9275423196270094,
 0.89077630510346,
 0.9537082539371149,
 0.9743876057367452]

alpha_07 = [2.0007898223421674,
 2.000237518445299,
 1.9994715103487886,
 1.9382541932994244,
 1.1038531609750617,
 0.9636895094139215,
 0.934419566904034,
 0.882088120021222,
 0.8904309171594724]

alpha_08 = [2.0028777798052273,
 2.0004219028047263,
 2.00488114900863,
 1.9671666000156018,
 1.3004634159557238,
 1.1203209246048824,
 1.0430041412949023,
 1.0003540553962178,
 0.9552239239958898]

alpha_09 = [2.008836816792085,
 1.9960944117571662,
 1.9959043202512452,
 1.9938772348723002,
 1.428781234786798,
 1.2512188228467234,
 1.1523493881097504,
 1.0739715564066543,
 1.036683940882398]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7.5))
# plt.plot(lr_list, alpha_06, linewidth = 3)
plt.plot(lr_list, alpha_07, linewidth = 3)
plt.plot(lr_list, alpha_08, linewidth = 3)
plt.plot(lr_list, alpha_09, linewidth = 3)
plt.plot(lr_list, alpha_cyc, linewidth = 3)

plt.xlabel(r'Mean of learning rate $\hat{\eta}$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
# bbox_to_anchor=(1.04,0.5)
legendList = [r'$p = 0.7$',r'$p = 0.8$',r'$p = 0.9$',r'$p = 1$ (cyclic lr)']
plt.legend(legendList, loc='best', fontsize=23)
plt.show()

# %%
# mc lr with different p values
# delta=0.05
alpha_06 = [2.002046524425199,
 1.9993057626601152,
 1.9646224357506248,
 1.6161651157544217,
 0.9808721745312605,
 0.9275423196270094,
 0.89077630510346,
 0.9537082539371149,
 0.9743876057367452]

alpha_07 = [2.0007898223421674,
 2.000237518445299,
 1.9994715103487886,
 1.9382541932994244,
 1.1038531609750617,
 0.9636895094139215,
 0.934419566904034,
 0.882088120021222,
 0.8904309171594724]

alpha_08 = [2.0028777798052273,
 2.0004219028047263,
 2.00488114900863,
 1.9671666000156018,
 1.3004634159557238,
 1.1203209246048824,
 1.0430041412949023,
 1.0003540553962178,
 0.9552239239958898]

alpha_09 = [2.008836816792085,
 1.9960944117571662,
 1.9959043202512452,
 1.9938772348723002,
 1.428781234786798,
 1.2512188228467234,
 1.1523493881097504,
 1.0739715564066543,
 1.036683940882398]

alpha_04 = [1.9943753571714917,
 1.9950639854821763,
 1.957120456741454,
 1.6824819879290065,
 0.9494395188129017,
 0.875474701010148,
 0.9799488114324543,
 0.9159566383564083,
 0.9186597032047429]

alpha_03 = [2.0001279737440205,
 1.9870249576420291,
 1.999514874384365,
 1.933101370983265,
 1.122724610672851,
 0.9828353759204994,
 0.929100507595582,
 0.8913551039301439,
 0.9175175543742821]

alpha_02 = [2.00697100867133,
 2.0119853260321996,
 1.9933699529453421,
 1.9697108011403963,
 1.317389505426751,
 1.1324853754127113,
 1.041015666486291,
 1.00491468812273,
 0.9520538288573255]

alpha_01 = [2.0051916622602155,
 1.9945705662745892,
 2.00490379217264,
 1.9827209049411674,
 1.4387004358208177,
 1.268236660419093,
 1.1531935022655535,
 1.086057667565457,
 1.0137602967847332]

alpha_0 = [1.9988285504412928,
 2.0010328841064706,
 2.0091861275393095,
 1.9870029968082032,
 1.5465389233210884,
 1.3788900217096625,
 1.252981598305959,
 1.1940963626417411,
 1.1024873141084652]

alpha_1 = [1.9963563423857555,
 2.0039873314793,
 2.001286985447247,
 1.9957829668936526,
 1.5398887595079216,
 1.3530620599289807,
 1.26730458591317,
 1.1873361180797293,
 1.1073351651498942]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7.5))
plt.plot(lr_list, alpha_0, linewidth = 3)
plt.plot(lr_list, alpha_01, linewidth = 3)
plt.plot(lr_list, alpha_02, linewidth = 3)
plt.plot(lr_list, alpha_03, linewidth = 3)
plt.plot(lr_list, alpha_04, linewidth = 3)
plt.plot(lr_list, alpha_06, linewidth = 3)
plt.plot(lr_list, alpha_07, linewidth = 3)
plt.plot(lr_list, alpha_08, linewidth = 3)
plt.plot(lr_list, alpha_09, linewidth = 3)
plt.plot(lr_list, alpha_1, linewidth = 3)

plt.xlabel(r'Mean of learning rate $\hat{\eta}$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
# bbox_to_anchor=(1.04,0.5)
legendList = [r'$p=0$',r'$p = 0.1$',r'$p = 0.2$',r'$p = 0.3$',r'$p = 0.4$',r'$p=0.6$',r'$p = 0.7$',r'$p = 0.8$',r'$p = 0.9$',r'$p = 1$']
plt.legend(legendList, loc='best', fontsize=15)
plt.show()

# %%
# mc lr with different batch size
# delta=0.05
# p = 0.6
alpha_10 = [2.002046524425199,
 1.9993057626601152,
 1.9646224357506248,
 1.6161651157544217,
 0.9808721745312605,
 0.9275423196270094,
 0.96077630510346,
 0.9537082539371149,
 0.9743876057367452]

alpha_5 =[0.9264896909148191,
 0.9621836353446682,
 0.9506348937605029,
 0.9761174946713548,
 0.9695425538228692,
 0.9609424562589681,
 0.9673843419640878,
 0.954107313506329,
 0.9746761937722437]

alpha_7 = [0.9042221668623771,
 0.8700888403966642,
 0.8933334380405398,
 0.957506602964338,
 0.895328100433898,
 0.9705782762630675,
 0.9462830725163469,
 0.9663269689546208,
 0.930257797257412]

alpha_15 = [2.0035171846882553,
 2.0135258646059153,
 2.0063125438309637,
 2.013460499228646,
 2.0012637555100925,
 2.0003798761587923,
 1.9981436627871332,
 1.9998216614799522,
 2.002280135675251]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7.5))
plt.plot(lr_list, alpha_15, linewidth = 3)
plt.plot(lr_list, alpha_10, linewidth = 3)
# plt.plot(lr_list, alpha_7, linewidth = 3)
plt.plot(lr_list, alpha_5, linewidth = 3)
# plt.plot(lr_list, alpha_cyc, linewidth = 3)

plt.xlabel(r'Mean of learning rate $\hat{\eta}$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
# bbox_to_anchor=(1.04,0.5)
legendList = [r'$batch=15$',r'$batch = 10$',r'$batch = 5$']
plt.legend(legendList, loc='best', fontsize=23)
plt.show()

# %%
# unif lr with different batch size
# delta=0.05

alpha_10 = [1.9992081559596,
 2.0058759615058332,
 1.9966414023637025,
 1.9888339310322185,
 1.3223480616710073,
 1.1545610117347485,
 1.0441591429818526,
 0.9973064473474609,
 0.9672450767340022]

alpha_5 =[0.9700783413836138,
 0.9546597864680119,
 0.904544079410688,
 0.9231340212818335,
 0.8954111632952743,
 0.9378181614711333,
 0.9890537042756602,
 0.9670302823223297,
 0.8527419243938376]

alpha_7 =[1.1729687493617813,
 1.0627197325762983,
 0.9984367321277543,
 0.9345199413471473,
 0.8842244827446193,
 0.9158282678401728,
 0.9370418156715172,
 0.9239248803386607,
 0.9450177261304024]

alpha_15 = [1.9978611534191966,
 2.0044053084263735,
 2.000695085810468,
 1.9991325974971241,
 2.0009896611850366,
 1.9985937372848606,
 2.008359144185032,
 2.002451931712333,
 2.0086479940508997]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7.5))
plt.plot(lr_list, alpha_15, linewidth = 3)
plt.plot(lr_list, alpha_10, linewidth = 3)
# plt.plot(lr_list, alpha_7, linewidth = 3)
plt.plot(lr_list, alpha_5, linewidth = 3)
# plt.plot(lr_list, alpha_cyc, linewidth = 3)

plt.xlabel(r'Mean of learning rate $\hat{\eta}$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
# bbox_to_anchor=(1.04,0.5)
legendList = [r'$batch=15$',r'$batch = 10$',r'$batch = 5$']
plt.legend(legendList, loc='best', fontsize=23)
plt.show()

# %%
# cyc lr with different batch size
# delta=0.05

alpha_10 = [1.9991720893978229,
 2.011298303694093,
 2.0008479594466153,
 1.9874978527323601,
 1.5428267534633262,
 1.3720664714152018,
 1.269155771649106,
 1.1805871763417242,
 1.0950724369206228]

alpha_5 = [0.959532605578557,
 0.9289879996308373,
 0.8703290561227857,
 0.8811398512176276,
 0.9908603951566133,
 0.9651772562390792,
 0.9565810347940601,
 0.9372771075289897,
 0.8873461148806024]

alpha_7 = [1.3954468822681436,
 1.2920632144781692,
 1.161125644300706,
 1.0791494555255483,
 0.9878826752653216,
 0.9550900680831578,
 0.9284114637828675,
 0.8752488157381402,
 0.8986744000965463]

alpha_15 = [2.003486981030688,
 1.9938059261214678,
 1.997572033406242,
 2.0001903070494245,
 2.006773515199711,
 2.0006186334523184,
 2.01266844327256,
 2.009809967978872,
 2.0119033679985248]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,7.5))
plt.plot(lr_list, alpha_15, linewidth = 3)
plt.plot(lr_list, alpha_10, linewidth = 3)
# plt.plot(lr_list, alpha_7, linewidth = 3)
plt.plot(lr_list, alpha_5, linewidth = 3)
# plt.plot(lr_list, alpha_cyc, linewidth = 3)

plt.xlabel(r'Mean of learning rate $\hat{\eta}$',fontsize=25)
plt.ylabel(r'Tail index $\alpha$',fontsize=25)
plt.tick_params(labelsize=25)
# bbox_to_anchor=(1.04,0.5)
legendList = [r'$batch=15$',r'$batch = 10$',r'$batch = 5$']
plt.legend(legendList, loc='best', fontsize=23)
plt.show()
